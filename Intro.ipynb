# %% [markdown]
# This is a basic ipython notebook to get you familiar with python and python notebooks

# %%
#Notebooks perform simple blocked compuations and save the results after exectuting
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %%
#What will happen when I run this block?
seconds_in_a_day

# %%
#Notebooks also allow you to import
import numpy as np
import nibabel as nib

# %%
#You can also run commands to the terminal by including a 
# !pip install scipy

# %%
#Python can do strings
A="Hello World!"
print(A)
# Out:
# Hello World!

# %%
#Python is interpreted which means that the type doesn't need to be specified and python will take a guess as to what it is
print(type(1.0))
print(type(1))
print(type(True))
# Out:
# <class 'float'>
# <class 'int'>
# <class 'bool'>

# %%
#But this can lead to issues as things might be interpreted incorrectly for instance in this control sequence below
a=1
if a:
  print(a)
else:
  print(0)
# Out:
# 1

# %%
#Python allows easy function definitions
def maximum(a,b):
  return a if a > b else b
#Use the return keyword

# %%
print(maximum(2,3))
# Out:
# 3

# %%
#To continue in a loop or function definition the number of tabs needs to be equal
def example_function(a):
  print("first line")
  print("second line")
  if(a):
    #Note there are two tabs here
    print(a)
  else:
    print("A was not true")
  return a

# %%
print(example_function(0))
# Out:
# first line
# second line
# A was not true
# 0

# %%
#We can also visualize using standard python tools
import matplotlib.pyplot as plt

# %%
plt.scatter(range(5),range(5))
